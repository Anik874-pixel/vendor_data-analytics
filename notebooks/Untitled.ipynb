# %%
import pandas as pd
import os
from sqlalchemy import create_engine
import logging
import time

logging.basicConfig(
    filename = "logs/ingestion_db.log",
    level = logging.DEBUG,
    format = "%(asctime)s - %(levelname)s - %(message)s",
    filemode = "a"
) 

engine = create_engine('sqlite:///inventory.db')

def ingest_db(df, table_name, engine):
    '''This function will ingest the dataframe into database table'''
    df.to_sql(table_name, con = engine, if_exists = 'replace', index = False)

def load_raw_data():
    '''This function will load the CSVs as dataframe and ingest into db'''
start = time.time()
for file in os.listdir('data'):
   if file.endswith('.csv'):
        print("Processing",file)
        df = pd.read_csv('data/' + file, nrows = 200000)
        print("Loaded Shape:", df.shape)
        logging.info(f'Ingesting {file} in db')
        ingest_db(df, file[:-4], engine)
end = time.time()
total_time = (end - start)/60
logging.info('----------Ingestion Complete---------')
logging.info(f'\nTotal Time Taken : {total_time} minutes')

if __name__ == '__main__':
    load_raw_data()
# Out:
# Processing begin_inventory.csv
# Loaded Shape: (200000, 9)
# Processing end_inventory.csv
# Loaded Shape: (200000, 9)
# Processing purchases.csv
# Loaded Shape: (200000, 16)
# Processing purchase_prices.csv
# Loaded Shape: (12261, 9)
# Processing sales.csv
# Loaded Shape: (200000, 14)
# Processing vendor_invoice.csv
# Loaded Shape: (5543, 10)

# %%
engine = create_engine('sqlite:///inventory.db')

# %%
os.listdir('data')
# Out:
# ['.ipynb_checkpoints',
#  'begin_inventory.csv',
#  'end_inventory.csv',
#  'purchases.csv',
#  'purchase_prices.csv',
#  'sales.csv',
#  'vendor_invoice.csv',
#  '__MACOSX']

# %%
def ingest_db(df, table_name, engine):
    '''This function will ingest the dataframe into database table'''
    df.to_sql(table_name, con = engine, if_exists = 'replace', index = False)

# %%
def load_raw_data():
    '''This function will load the CSVs as dataframe and ingest into db'''
    start = time.time()
  for file in os.listdir('data'):
    if '.csv' in file:
        print("Processing",file)
        df = pd.read_csv('data/' + file, nrows = 200000)
        print("Loaded Shape:", df.shape)
        logging.info(f'Ingesting {file} in db')
        ingest_db(df, file[:-4], engine)
    end = time.time()
    total_time = (end - start)/60
    logging.info('----------Ingestion Complete---------')
    logging.info(f'\nTotal Time Taken : {total_time} minutes')
# Out:
# Processing begin_inventory.csv
# Loaded Shape: (200000, 9)
# Processing end_inventory.csv
# Loaded Shape: (200000, 9)
# Processing purchases.csv
# Loaded Shape: (200000, 16)
# Processing purchase_prices.csv
# Loaded Shape: (12261, 9)
# Processing sales.csv
# Loaded Shape: (200000, 14)
# Processing vendor_invoice.csv
# Loaded Shape: (5543, 10)

# %%
from sqlalchemy import inspect
inspect(engine).get_table_names()
# Out:
# ['begin_inventory',
#  'end_inventory',
#  'purchase_prices',
#  'purchases',
#  'sales',
#  'vendor_invoice']
